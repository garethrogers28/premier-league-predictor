# %% [markdown]
# # **Data Collection**

# %% [markdown]
# ## Objectives
#
# * Collect the Premier League player statistics dataset programmatically from Kaggle.
# * Store the collected raw datasets in the `data/raw` folder.
# * Inspect each dataset to understand its structure and identify any inconsistencies.
# * Prepare the datasets for merging into a single processed DataFrame.
#
# ## Inputs
#
# * Premier League player statistics dataset collected from Kaggle.
#
# ## Outputs
#
# * Raw Premier League player statistics CSV files stored in the `data/raw` folder.
# * A single merged Premier League player statistics DataFrame.
# * A processed dataset saved to the `data/processed` folder for use in later notebooks.
#
# ## Additional Comments
#
# * The raw datasets are collected programmatically before being processed.
# * The original raw data is not modified during the processing stages.

# %% [markdown]
# ---

# %% [markdown]
# ### Change working directory

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\code\\premier-league-predictor\\premier-league-predictor\\jupyter_notebooks'

# %%
os.chdir(r"C:\code\premier-league-predictor\premier-league-predictor")
print("You set a new current directory")
# Out:
# You set a new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'C:\\code\\premier-league-predictor\\premier-league-predictor'

# %% [markdown]
# ### Import packages
#
# `pandas` is used for loading, inspecting and processing the datasets.
#
# The Kaggle API is used to collect the original Premier League player statistics dataset programmatically from Kaggle.

# %%
import pandas as pd

# %% [markdown]
# ### Collect dataset from Kaggle
#
# The Premier League player statistics dataset is collected programmatically from Kaggle using the Kaggle API and stored in the `data/raw` directory.
#
# This provides a reproducible data collection mechanism before the raw datasets are inspected, processed and merged.

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

api.dataset_download_files(
    "krishanthbarkav/english-premier-leagueepl-player-statistics",
    path="data/raw",
    unzip=True
)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/krishanthbarkav/english-premier-leagueepl-player-statistics

# %% [markdown]
# ---

# %% [markdown]
# ### Load all Premier League datasets
#
# The Premier League player statistics datasets are loaded from the `data/raw` directory into pandas DataFrames. These datasets represent multiple seasons and will be standardised before being combined into a single dataset.

# %%
data_path = "data/raw"

# %%
os.listdir(data_path)
# Out:
# ['pl_15-16.csv',
#  'pl_16-17.csv',
#  'pl_17-18.csv',
#  'pl_18-19.csv',
#  'pl_19-20.csv',
#  'pl_20-21.csv',
#  'pl_21-22.csv',
#  'pl_22-23.csv',
#  'pl_23-24.csv']

# %%
csv_files = os.listdir(data_path)
csv_files
# Out:
# ['pl_15-16.csv',
#  'pl_16-17.csv',
#  'pl_17-18.csv',
#  'pl_18-19.csv',
#  'pl_19-20.csv',
#  'pl_20-21.csv',
#  'pl_21-22.csv',
#  'pl_22-23.csv',
#  'pl_23-24.csv']

# %%
file_name = csv_files[0]
file_name
# Out:
# 'pl_15-16.csv'

# %%
file_path = os.path.join(data_path, file_name)
file_path
# Out:
# 'data/raw\\pl_15-16.csv'

# %% [markdown]
# ### Inspect a single file first
#
# The first dataset is explored to understand its structure, identify the available features, and detect any issues before processing all seasons.

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0                Name    Position  Appearances  Clean sheets  \
# 0           0     Rolando Aarons   Midfielder           10           NaN
# 1           1         Almen Abdi   Midfielder           32           NaN
# 2           2  Abdul Rahman Baba     Defender           15           2.0
# 3           3        Mehdi Abeid   Midfielder            0           NaN
# 4           4      Tammy Abraham      Forward            2           NaN
#
#    Goals conceded  Tackles Tackle success %  Last man tackles  Blocked shots  \
# 0             NaN     13.0              77%               NaN            0.0
# 1             NaN     83.0              78%               NaN           10.0
# 2            13.0     47.0              83%               0.0            1.0
# 3             NaN      0.0               0%               NaN            0.0
# 4             NaN      0.0              NaN               NaN            1.0
#
# ...

# %%
df.shape
# Out:
# (757, 54)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Position', 'Appearances', 'Clean sheets',
#        'Goals conceded', 'Tackles', 'Tackle success %', 'Last man tackles',
#        'Blocked shots', 'Interceptions', 'Clearances', 'Headed Clearance',
#        'Clearances off line', 'Recoveries', 'Duels won', 'Duels lost',
#        'Successful 50/50s', 'Aerial battles won', 'Aerial battles lost',
#        'Own goals', 'Errors leading to goal', 'Assists', 'Passes',
#        'Passes per match', 'Big chances created', 'Crosses',
#        'Cross accuracy %', 'Through balls', 'Accurate long balls',
#        'Yellow cards', 'Red cards', 'Fouls', 'Offsides', 'Goals',
#        'Headed goals', 'Goals with right foot', 'Goals with left foot',
#        'Hit woodwork', 'Goals per match', 'Penalties scored',
#        'Freekicks scored', 'Shots', 'Shots on target', 'Shooting accuracy %',
#        'Big chances missed', 'Saves', 'Penalties saved', 'Punches',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 54 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              757 non-null    int64
#  1   Name                    757 non-null    object
#  2   Position                757 non-null    object
#  3   Appearances             757 non-null    int64
#  4   Clean sheets            322 non-null    float64
#  5   Goals conceded          322 non-null    float64
#  6   Tackles                 681 non-null    float64
#  7   Tackle success %        514 non-null    object
#  8   Last man tackles        246 non-null    float64
#  9   Blocked shots           681 non-null    float64
#  10  Interceptions           681 non-null    float64
#  11  Clearances              681 non-null    float64
#  12  Headed Clearance        681 non-null    float64
#  13  Clearances off line     246 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Name                        0
# Position                    0
# Appearances                 0
# Clean sheets              435
# Goals conceded            435
# Tackles                    76
# Tackle success %          243
# Last man tackles          511
# Blocked shots              76
# Interceptions              76
# Clearances                 76
# Headed Clearance           76
# Clearances off line       511
# Recoveries                243
# Duels won                 243
# Duels lost                243
# Successful 50/50s         243
# Aerial battles won        243
# Aerial battles lost       243
# Own goals                 435
# Errors leading to goal    167
# Assists                     0
# Passes                      0
# Passes per match            0
# Big chances created        76
# Crosses                    76
# Cross accuracy %          243
# Through balls             243
# Accurate long balls       167
# Yellow cards                0
# ...

# %% [markdown]
# ### Load all datasets into memory
#
# Now that the structure of a single file has been inspected, all CSV files in `data/raw` are loaded into a list of DataFrames. A `Season` column is added during loading so that each player record retains the season it belongs to before the datasets are merged.

# %%
season_data = []

seasons = [
    "2015-16",
    "2016-17",
    "2017-18",
    "2018-19",
    "2019-20",
    "2020-21",
    "2021-22",
    "2022-23",
    "2023-24",
]

# %%
csv_files
# Out:
# ['pl_15-16.csv',
#  'pl_16-17.csv',
#  'pl_17-18.csv',
#  'pl_18-19.csv',
#  'pl_19-20.csv',
#  'pl_20-21.csv',
#  'pl_21-22.csv',
#  'pl_22-23.csv',
#  'pl_23-24.csv']

# %%
for file_name, season in zip(csv_files, seasons):
    file_path = os.path.join(data_path, file_name)
    df = pd.read_csv(file_path)

    df["Season"] = season

    season_data.append(df)

# %%
"Season" in season_data[0].columns
# Out:
# True

# %%
len(season_data)
# Out:
# 9

# %%
type(season_data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
season_data[0].shape
# Out:
# (757, 55)

# %% [markdown]
# ### Check for column inconsistencies across seasons
#
# The datasets are compared to identify any structural differences before merging. This includes checking for missing or additional columns, differences in column names, and inconsistencies in column order across seasons.

# %%
for i, season_df in enumerate(season_data):
    print(i, season_df.shape)
# Out:
# 0 (757, 55)
# 1 (839, 55)
# 2 (793, 55)
# 3 (884, 55)
# 4 (974, 55)
# 5 (862, 55)
# 6 (989, 54)
# 7 (1092, 54)
# 8 (1016, 54)

# %%
set(season_data[0].columns) - set(season_data[6].columns)
# Out:
# {'Big chances created', 'Goals conceded', 'Penalties saved', 'Unnamed: 0'}

# %% [markdown]
# ### Remove unnecessary index column
#
# Some CSV files were exported with the DataFrame index saved as a column called `Unnamed: 0`. This column is not a player statistic and is removed before merging the datasets.

# %%
set(season_data[5].columns) - set(season_data[0].columns)
# Out:
# {'Big Chances Created', 'Goals Conceded', 'Penalties Saved'}

# %% [markdown]
# ### Standardise column names
#
# Although the datasets contained the same features, three column names used different capitalisation between seasons (e.g. `Big chances created` and `Big Chances Created`). These column names were standardised to ensure a consistent schema before merging the datasets.

# %%
for i, season_df in enumerate(season_data):
    print(i, list(season_df.columns))
# Out:
# 0 ['Unnamed: 0', 'Name', 'Position', 'Appearances', 'Clean sheets', 'Goals conceded', 'Tackles', 'Tackle success %', 'Last man tackles', 'Blocked shots', 'Interceptions', 'Clearances', 'Headed Clearance', 'Clearances off line', 'Recoveries', 'Duels won', 'Duels lost', 'Successful 50/50s', 'Aerial battles won', 'Aerial battles lost', 'Own goals', 'Errors leading to goal', 'Assists', 'Passes', 'Passes per match', 'Big chances created', 'Crosses', 'Cross accuracy %', 'Through balls', 'Accurate long balls', 'Yellow cards', 'Red cards', 'Fouls', 'Offsides', 'Goals', 'Headed goals', 'Goals with right foot', 'Goals with left foot', 'Hit woodwork', 'Goals per match', 'Penalties scored', 'Freekicks scored', 'Shots', 'Shots on target', 'Shooting accuracy %', 'Big chances missed', 'Saves', 'Penalties saved', 'Punches', 'High Claims', 'Catches', 'Sweeper clearances', 'Throw outs', 'Goal Kicks', 'Season']
# ...

# %%
for season_df in season_data:
    if 'Unnamed: 0' in season_df.columns:
        season_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
for i, season_df in enumerate(season_data):
    print(i, season_df.shape)
# Out:
# 0 (757, 54)
# 1 (839, 54)
# 2 (793, 54)
# 3 (884, 54)
# 4 (974, 54)
# 5 (862, 54)
# 6 (989, 54)
# 7 (1092, 54)
# 8 (1016, 54)

# %%
for season_df in season_data:
    season_df.rename(
        columns={
            "Big Chances Created": "Big chances created",
            "Goals Conceded": "Goals conceded",
            "Penalties Saved": "Penalties saved",
        },
        inplace=True,
    )

# %%
season_data[7].columns
# Out:
# Index(['Name', 'Position', 'Appearances', 'Goals', 'Goals per match',
#        'Headed goals', 'Goals with right foot', 'Goals with left foot',
#        'Penalties scored', 'Freekicks scored', 'Shots', 'Shots on target',
#        'Shooting accuracy %', 'Hit woodwork', 'Big chances missed', 'Assists',
#        'Passes', 'Passes per match', 'Big chances created', 'Crosses',
#        'Cross accuracy %', 'Through balls', 'Accurate long balls',
#        'Yellow cards', 'Red cards', 'Fouls', 'Offsides', 'Tackles',
#        'Tackle success %', 'Blocked shots', 'Interceptions', 'Clearances',
#        'Headed Clearance', 'Recoveries', 'Duels won', 'Duels lost',
#        'Successful 50/50s', 'Aerial battles won', 'Aerial battles lost',
#        'Errors leading to goal', 'Saves', 'Penalties saved', 'Punches',
#        'High Claims', 'Catches', 'Sweeper clearances', 'Throw outs',
#        'Goal Kicks', 'Clean sheets', 'Goals conceded', 'Own goals',
# ...

# %%
season_data[0].columns
# Out:
# Index(['Name', 'Position', 'Appearances', 'Clean sheets', 'Goals conceded',
#        'Tackles', 'Tackle success %', 'Last man tackles', 'Blocked shots',
#        'Interceptions', 'Clearances', 'Headed Clearance',
#        'Clearances off line', 'Recoveries', 'Duels won', 'Duels lost',
#        'Successful 50/50s', 'Aerial battles won', 'Aerial battles lost',
#        'Own goals', 'Errors leading to goal', 'Assists', 'Passes',
#        'Passes per match', 'Big chances created', 'Crosses',
#        'Cross accuracy %', 'Through balls', 'Accurate long balls',
#        'Yellow cards', 'Red cards', 'Fouls', 'Offsides', 'Goals',
#        'Headed goals', 'Goals with right foot', 'Goals with left foot',
#        'Hit woodwork', 'Goals per match', 'Penalties scored',
#        'Freekicks scored', 'Shots', 'Shots on target', 'Shooting accuracy %',
#        'Big chances missed', 'Saves', 'Penalties saved', 'Punches',
#        'High Claims', 'Catches', 'Sweeper clearances', 'Throw outs',
# ...

# %% [markdown]
# ### Align column order across all seasons
#
# Although all datasets contain the same columns, one season stores them in a different order. To ensure a consistent dataset structure before merging, the column order is aligned using the first season as the reference.

# %%
season_data[0].columns[3]
# Out:
# 'Clean sheets'

# %%
season_data[7].columns[3]
# Out:
# 'Goals'

# %%
for i, (col1, col2) in enumerate(zip(season_data[0].columns, season_data[7].columns)):
    if col1 != col2:
        print(f"{i}: {col1} -> {col2}")
# Out:
# 3: Clean sheets -> Goals
# 4: Goals conceded -> Goals per match
# 5: Tackles -> Headed goals
# 6: Tackle success % -> Goals with right foot
# 7: Last man tackles -> Goals with left foot
# 8: Blocked shots -> Penalties scored
# 9: Interceptions -> Freekicks scored
# 10: Clearances -> Shots
# 11: Headed Clearance -> Shots on target
# 12: Clearances off line -> Shooting accuracy %
# 13: Recoveries -> Hit woodwork
# 14: Duels won -> Big chances missed
# 15: Duels lost -> Assists
# 16: Successful 50/50s -> Passes
# 17: Aerial battles won -> Passes per match
# 18: Aerial battles lost -> Big chances created
# 19: Own goals -> Crosses
# 20: Errors leading to goal -> Cross accuracy %
# 21: Assists -> Through balls
# 22: Passes -> Accurate long balls
# 23: Passes per match -> Yellow cards
# 24: Big chances created -> Red cards
# 25: Crosses -> Fouls
# 26: Cross accuracy % -> Offsides
# 27: Through balls -> Tackles
# 28: Accurate long balls -> Tackle success %
# ...

# %%
season_data[7] = season_data[7][season_data[0].columns]
season_data[7].columns.equals(season_data[0].columns)
# Out:
# True

# %%
reference_columns = season_data[0].columns

for index, season_df in enumerate(season_data):
    season_data[index] = season_df[reference_columns]

# %%
for index, season_df in enumerate(season_data):
    print(index, season_df.columns.equals(reference_columns))
# Out:
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True

# %% [markdown]
# ### Merge all season datasets
#
# After standardising the dataset structure, the individual season DataFrames are combined into a single DataFrame. This creates one consolidated dataset that will be passed to the data cleaning stage in the following notebook.

# %%
all_players_df = pd.concat(season_data, ignore_index=True)

# %% [markdown]
# ### Verify merged dataset
#
# The merged dataset is checked to confirm that the new `Season` column has been retained alongside the original player statistics. This ensures each observation can be traced back to the season from which it originated.

# %%
all_players_df.shape
# Out:
# (8206, 54)

# %%
all_players_df.head()
# Out:
#                  Name    Position  Appearances  Clean sheets  Goals conceded  \
# 0     Rolando Aarons   Midfielder           10           NaN             NaN
# 1         Almen Abdi   Midfielder           32           NaN             NaN
# 2  Abdul Rahman Baba     Defender           15           2.0            13.0
# 3        Mehdi Abeid   Midfielder            0           NaN             NaN
# 4      Tammy Abraham      Forward            2           NaN             NaN
#
#    Tackles Tackle success %  Last man tackles  Blocked shots  Interceptions  \
# 0     13.0              77%               NaN            0.0            6.0
# 1     83.0              78%               NaN           10.0           32.0
# 2     47.0              83%               0.0            1.0           23.0
# 3      0.0               0%               NaN            0.0            0.0
# 4      0.0              NaN               NaN            1.0            0.0
#
# ...

# %%
all_players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8206 entries, 0 to 8205
# Data columns (total 54 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    8206 non-null   object
#  1   Position                8206 non-null   object
#  2   Appearances             8206 non-null   int64
#  3   Clean sheets            3579 non-null   float64
#  4   Goals conceded          3579 non-null   float64
#  5   Tackles                 7244 non-null   float64
#  6   Tackle success %        5531 non-null   object
#  7   Last man tackles        2617 non-null   float64
#  8   Blocked shots           7244 non-null   float64
#  9   Interceptions           7244 non-null   float64
#  10  Clearances              7244 non-null   float64
#  11  Headed Clearance        7244 non-null   float64
#  12  Clearances off line     2617 non-null   float64
#  13  Recoveries              5531 non-null   float64
# ...

# %% [markdown]
# ### Save merged dataset
#
# The merged dataset is saved to the `data/processed` directory. This provides a single, consistent dataset that will be loaded by the data cleaning notebook.

# %%
output_path = "data/processed/all_players.csv"

all_players_df.to_csv(output_path, index=False)

# %%
os.listdir("data/processed")
# Out:
# ['all_players.csv',
#  'all_players_cleaned.csv',
#  'cleaned_players.csv',
#  'engineered_players.csv']

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusions and Next Steps
#
# ### Conclusions
#
# This notebook successfully collected the Premier League player statistics dataset programmatically from Kaggle using the Kaggle API.
#
# The dataset contains player statistics from nine Premier League seasons. Before merging, the datasets were prepared by:
#
# - Removing unnecessary index columns (`Unnamed: 0`).
# - Standardising inconsistent column names.
# - Aligning column order across all seasons.
# - Adding a `Season` column to preserve the season associated with each player record.
#
# The nine datasets were then combined into a single DataFrame containing **8,206 player records** and **54 features**, which was saved to the `data/processed` directory for further analysis.
#
# ### Next Steps
#
# The next notebook will focus on data cleaning. This will include:
#
# - Investigating missing values.
# - Checking for duplicate records.
# - Validating data types.
# - Identifying any additional data quality issues.
